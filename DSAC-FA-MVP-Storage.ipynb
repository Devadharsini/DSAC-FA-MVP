# %%
#pip install yfinance

# %%
import pandas as pd
import datetime
import pandas_datareader.data as web
from pandas import Series, DataFrame


start = datetime.datetime(2021, 1, 1)
end = datetime.datetime(2022, 12, 31)

df = web.DataReader(['TSLA','F'], 'yahoo', start, end)
df.tail()
# Out:
# Attributes   Adj Close                  Close                   High  \
# Symbols           TSLA          F        TSLA          F        TSLA
# Date
# 2022-02-10  904.549988  18.080000  904.549988  18.080000  943.809998
# 2022-02-11  860.000000  17.549999  860.000000  17.549999  915.960022
# 2022-02-14  875.760010  17.459999  875.760010  17.459999  898.880005
# 2022-02-15  922.429993  18.080000  922.429993  18.080000  923.000000
# 2022-02-16  923.390015  18.010000  923.390015  18.010000  926.429993
#
# Attributes                    Low                   Open             \
# Symbols             F        TSLA          F        TSLA          F
# Date
# 2022-02-10  18.629999  896.700012  17.920000  908.369995  17.969999
# 2022-02-11  18.360001  850.700012  17.420000  909.630005  18.100000
# 2022-02-14  17.730000  853.150024  17.290001  861.570007  17.510000
# 2022-02-15  18.129999  893.380005  17.719999  900.000000  17.799999
# 2022-02-16  18.209999  901.210022  17.740000  914.049988  17.889999
#
# Attributes      Volume
# Symbols           TSLA           F
# Date
# 2022-02-10  22042300.0  76195300.0
# 2022-02-11  26492700.0  94362600.0
# 2022-02-14  22515100.0  78527800.0
# 2022-02-15  19216500.0  66043600.0
# 2022-02-16  17027700.0  57277900.0

# %%
import csv 
import json 
csvFilePath = r'stockstorage.csv'
jsonFilePath = r'stockstorage.json'
def csv_to_json(csvFilePath, jsonFilePath):
    jsonArray = []
      
    #read csv file
    with open(csvFilePath, encoding='utf-8') as csvf: 
        #load csv file data using csv library's dictionary reader
        csvReader = csv.DictReader(csvf) 

        #convert each csv row into python dict
        for row in csvReader: 
            #add this python dict to json array
            jsonArray.append(row)
  
    #convert python jsonArray to JSON String and write to file
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf: 
        jsonString = json.dumps(jsonArray, indent=4)
        jsonf.write(jsonString)
          
csvFilePath = r'stockstorage.csv'
jsonFilePath = r'stockstorage.json'
csv_to_json(csvFilePath, jsonFilePath)

# %%
import firebase_admin
import google.cloud
from firebase_admin import credentials, firestore

if not firebase_admin.initialize_app:
    cred = credentials.Certificate("C:/Users/dhars/DSAC-FA-MVP-Configuration.json")
    app = firebase_admin.initialize_app(cred)

store = firestore.client()
doc_ref = store.collection(u'financialstockdetails')
doc_ref.add({u'name':u'test',u'added':u'just now'})
#doc_ref.add(x),tmp
#df=pd.read_csv('stockstorage.csv')
#tmp = df.to_dict(orient='records')
#list(map(lambda x:doc_ref.add(x),tmp))

#export
#docs = doc_ref.stream()
#for doc in docs:
#    print(f'{doc.High}=>{doc.to_dict()}')
#try:
#    docs = doc_ref.get()
#    for doc in docs:
#        print(u'Doc Data:{}'.format(doc.to_dict()))
#except google.cloud.exceptions.NotFound:
#    print(u'Missing data')
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python38\site-packages\google\api_core\grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      65         try:
# ---> 66             return callable_(*args, **kwargs)
#      67         except grpc.RpcError as exc:
#
# ~\anaconda3\lib\site-packages\grpc\_channel.py in __call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     945                                       wait_for_ready, compression)
# --> 946         return _end_unary_response_blocking(state, call, False, None)
#     947
#
# ~\anaconda3\lib\site-packages\grpc\_channel.py in _end_unary_response_blocking(state, call, with_call, deadline)
#     848     else:
# --> 849         raise _InactiveRpcError(state)
#     850
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.RESOURCE_EXHAUSTED
# 	details = "Quota exceeded."
# 	debug_error_string = "{"created":"@1645080836.605000000","description":"Error received from peer ipv4:142.250.196.42:443","file":"src/core/lib/surface/call.cc","file_line":1075,"grpc_message":"Quota exceeded.","grpc_status":8}"
# >
#
# The above exception was the direct cause of the following exception:
#
# ResourceExhausted                         Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python38\site-packages\google\api_core\retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     189         try:
# --> 190             return target()
#     191
#
# ~\AppData\Roaming\Python\Python38\site-packages\google\api_core\grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      67         except grpc.RpcError as exc:
# ---> 68             raise exceptions.from_grpc_error(exc) from exc
#      69
#
# ResourceExhausted: 429 Quota exceeded.
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# <ipython-input-74-b85cdd25e389> in <module>
#       9 store = firestore.client()
#      10 doc_ref = store.collection(u'financialstockdetails')
# ---> 11 doc_ref.add({u'name':u'test',u'added':u'just now'})
#      12 #doc_ref.add(x),tmp
#      13 #df=pd.read_csv('stockstorage.csv')
#
# ~\AppData\Roaming\Python\Python38\site-packages\google\cloud\firestore_v1\collection.py in add(self, document_data, document_id, retry, timeout)
#     105             document_data, document_id, retry, timeout,
#     106         )
# --> 107         write_result = document_ref.create(document_data, **kwargs)
#     108         return write_result.update_time, document_ref
#     109
#
# ~\AppData\Roaming\Python\Python38\site-packages\google\cloud\firestore_v1\document.py in create(self, document_data, retry, timeout)
#      97         """
#      98         batch, kwargs = self._prep_create(document_data, retry, timeout)
# ---> 99         write_results = batch.commit(**kwargs)
#     100         return _first_write_result(write_results)
#     101
#
# ~\AppData\Roaming\Python\Python38\site-packages\google\cloud\firestore_v1\batch.py in commit(self, retry, timeout)
#      57         request, kwargs = self._prep_commit(retry, timeout)
#      58
# ---> 59         commit_response = self._client._firestore_api.commit(
#      60             request=request, metadata=self._client._rpc_metadata, **kwargs,
#      61         )
#
# ~\AppData\Roaming\Python\Python38\site-packages\google\cloud\firestore_v1\services\firestore\client.py in commit(self, request, database, writes, retry, timeout, metadata)
#     813
#     814         # Send the request.
# --> 815         response = rpc(request, retry=retry, timeout=timeout, metadata=metadata,)
#     816
#     817         # Done; return the response.
#
# ~\AppData\Roaming\Python\Python38\site-packages\google\api_core\gapic_v1\method.py in __call__(self, timeout, retry, *args, **kwargs)
#     152             kwargs["metadata"] = metadata
#     153
# --> 154         return wrapped_func(*args, **kwargs)
#     155
#     156
#
# ~\AppData\Roaming\Python\Python38\site-packages\google\api_core\retry.py in retry_wrapped_func(*args, **kwargs)
#     281                 self._initial, self._maximum, multiplier=self._multiplier
#     282             )
# --> 283             return retry_target(
#     284                 target,
#     285                 self._predicate,
#
# ~\AppData\Roaming\Python\Python38\site-packages\google\api_core\retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     203         if deadline_datetime is not None:
#     204             if deadline_datetime <= now:
# --> 205                 raise exceptions.RetryError(
#     206                     "Deadline of {:.1f}s exceeded while calling target function".format(
#     207                         deadline
#
# RetryError: Deadline of 60.0s exceeded while calling target function, last exception: 429 Quota exceeded.

# %%
import csv
import firebase_admin
import google.cloud
from firebase_admin import credentials, firestore

if not firebase_admin.initialize_app:
    cred = credentials.Certificate("C:/Users/dhars/DSAC-FA-MVP-Configuration.json")
    app = firebase_admin.initialize_app(cred)

store = firestore.client()

file_path = "stockstorage.csv"
collection_name = "financialstockdetails"


def batch_data(iterable, n=1):
    l = len(iterable)
    for ndx in range(0, l, n):
        yield iterable[ndx:min(ndx + n, l)]


data = []
headers = []
with open(file_path) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            for header in row:
                headers.append(header)
            line_count += 1
        else:
            obj = {}
            for idx, item in enumerate(row):
                obj[headers[idx]] = item
            data.append(obj)
            line_count += 1
    print(f'Processed {line_count} lines.')

for batched_data in batch_data(data, 400):
    batch = store.batch()
    for data_item in batched_data:
        doc_ref = store.collection(collection_name).document()
        batch.set(doc_ref, data_item)
    batch.commit()

print('Done')
# Out:
# Processed 30 lines.
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python38\site-packages\google\api_core\grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      65         try:
# ---> 66             return callable_(*args, **kwargs)
#      67         except grpc.RpcError as exc:
#
# ~\anaconda3\lib\site-packages\grpc\_channel.py in __call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     945                                       wait_for_ready, compression)
# --> 946         return _end_unary_response_blocking(state, call, False, None)
#     947
#
# ~\anaconda3\lib\site-packages\grpc\_channel.py in _end_unary_response_blocking(state, call, with_call, deadline)
#     848     else:
# --> 849         raise _InactiveRpcError(state)
#     850
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.RESOURCE_EXHAUSTED
# 	details = "Quota exceeded."
# 	debug_error_string = "{"created":"@1645080909.212000000","description":"Error received from peer ipv4:142.250.196.42:443","file":"src/core/lib/surface/call.cc","file_line":1075,"grpc_message":"Quota exceeded.","grpc_status":8}"
# >
#
# The above exception was the direct cause of the following exception:
#
# ResourceExhausted                         Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python38\site-packages\google\api_core\retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     189         try:
# --> 190             return target()
#     191
#
# ~\AppData\Roaming\Python\Python38\site-packages\google\api_core\grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      67         except grpc.RpcError as exc:
# ---> 68             raise exceptions.from_grpc_error(exc) from exc
#      69
#
# ResourceExhausted: 429 Quota exceeded.
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# <ipython-input-75-6ac1b7e52013> in <module>
#      43         doc_ref = store.collection(collection_name).document()
#      44         batch.set(doc_ref, data_item)
# ---> 45     batch.commit()
#      46
#      47 print('Done')
#
# ~\AppData\Roaming\Python\Python38\site-packages\google\cloud\firestore_v1\batch.py in commit(self, retry, timeout)
#      57         request, kwargs = self._prep_commit(retry, timeout)
#      58
# ---> 59         commit_response = self._client._firestore_api.commit(
#      60             request=request, metadata=self._client._rpc_metadata, **kwargs,
#      61         )
#
# ~\AppData\Roaming\Python\Python38\site-packages\google\cloud\firestore_v1\services\firestore\client.py in commit(self, request, database, writes, retry, timeout, metadata)
#     813
#     814         # Send the request.
# --> 815         response = rpc(request, retry=retry, timeout=timeout, metadata=metadata,)
#     816
#     817         # Done; return the response.
#
# ~\AppData\Roaming\Python\Python38\site-packages\google\api_core\gapic_v1\method.py in __call__(self, timeout, retry, *args, **kwargs)
#     152             kwargs["metadata"] = metadata
#     153
# --> 154         return wrapped_func(*args, **kwargs)
#     155
#     156
#
# ~\AppData\Roaming\Python\Python38\site-packages\google\api_core\retry.py in retry_wrapped_func(*args, **kwargs)
#     281                 self._initial, self._maximum, multiplier=self._multiplier
#     282             )
# --> 283             return retry_target(
#     284                 target,
#     285                 self._predicate,
#
# ~\AppData\Roaming\Python\Python38\site-packages\google\api_core\retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     203         if deadline_datetime is not None:
#     204             if deadline_datetime <= now:
# --> 205                 raise exceptions.RetryError(
#     206                     "Deadline of {:.1f}s exceeded while calling target function".format(
#     207                         deadline
#
# RetryError: Deadline of 60.0s exceeded while calling target function, last exception: 429 Quota exceeded.

# %%
import firebase_admin
from firebase_admin import credentials, firestore

if not firebase_admin.initialize_app:
    cred = credentials.Certificate("C:/Users/dhars/DSAC-FA-MVP-Configuration.json")
    app = firebase_admin.initialize_app(cred)

store = firestore.client()
doc_ref = store.collection(u'stockdetails')

data = []

docs = doc_ref.get()
for doc in docs:
    df1 = data.append(doc.to_dict())
print(len(data))
print(data)
# Out:
# 1651
# [{'0.0': '0.0', '0.06411892271883785': '69.09064250484137', '0.05589848336539253': '68.12164366122613', '1031788800': '23600100', '0.0613783560693264': '68.39446258544922'}, {'0.05589848336539253': '55.60073190339519', '1031788800': '19907000', '0.0': '0.0', '0.06411892271883785': '56.2143853321648', '0.0613783560693264': '55.74020004272461'}, {'0.0': '0.0', '0.06411892271883785': '27.973324973235353', '0.05589848336539253': '27.36058624270405', '1031788800': '40685000', '0.0613783560693264': '27.615894317626953'}, {'0.05589848336539253': '3.3391013145446777', '0.06411892271883785': '3.4229484540233566', '0.0613783560693264': '3.3391013145446777', '1031788800': '58326400', '0.0': '0.0'}, {'0.